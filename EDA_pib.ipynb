# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.

from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd
from dash.dependencies import Input, Output
import plotly.graph_objects as go
from datetime import datetime 

app = Dash(__name__)



pd.read_csv("dados_pib.csv")
df = pd.read_csv("dados_pib.csv")
df2.columns = ["Data","pib_mensal","ipca","100","deflator","pib_real"]
df['Data'] = pd.to_datetime(df['Data'],dayfirst=True)
dff = df.set_index(['Data'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data'
#
# ...

# %%
dff
# Out:
#             pib_mensal   ipca           100      pib_real
# Data
# 1990-01-01         0.2  67.55  1.675500e+02  1.202790e+06
# 1990-01-02         0.4  75.73  2.944356e+02  6.844535e+05
# 1990-01-03         0.8  82.39  5.370211e+02  3.752692e+05
# 1990-01-04         0.7  15.52  6.203668e+02  3.248521e+05
# 1990-01-05         0.8   7.59  6.674526e+02  3.019353e+05
# ...                ...    ...           ...           ...
# 2022-01-09    829534.3  -0.29  1.972525e+08  1.021673e+00
# 2022-01-10    832985.7   0.59  1.984163e+08  1.015680e+00
# 2022-01-11    835550.2   0.41  1.992298e+08  1.011533e+00
# 2022-01-12    841037.0   0.62  2.004650e+08  1.005300e+00
# 2023-01-01    811514.5   0.53  2.015275e+08  1.000000e+00
#
# [397 rows x 4 columns]

# %%
fig =go.Figure()
fig = px.line(dff, y="pib_real", color=px.Constant("pib real"))
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
fig = px.line(dff, y="pib_mensal", color=px.Constant("pib mensal"))
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Arturo\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...
